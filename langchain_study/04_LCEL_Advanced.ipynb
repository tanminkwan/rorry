# %%
# API Key를 환경변수로 관리하기 위한 설정 파일

from dotenv import load_dotenv

# API Key 정보로드
load_dotenv()

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

# ChatOpenAI 모델을 인스턴스화합니다.
model = ChatOpenAI()

prompt = ChatPromptTemplate.from_template("{topic}에 대하여 3문장으로 설명해줘.")

chain = prompt | model

# %% [markdown]
# ### 입력 스키마
# - Runnable에 의해 수락된 입력들에 대한 설명
# - Runnable의 구조로부터 동적으로 생성된 Pydantic 모델
# - .schema() 는 JSON 표현으로 출력

# %%
chain.input_schema.schema()

# %%
input_schema = {
    "type": "object",
    "properties": {
        "name": {"type": "string"},
        "age": {"type": "integer", "minimun": 0},
    },
    "required": ["name", "age"],
}

# %%
# model 의 input schema 를 출력합니다.
model.input_schema.schema()

# %% [markdown]
# ### 출력 스키마

# %%
# chain의 output schema
# - AIMessage
# - HumanMessage
# - ChatMessage
# - SystemMessage
chain.output_schema.schema()

# %% [markdown]
# ### stream : 실시간 출력

# %%
for s in chain.stream({"topic":"멀티모달"}):
    # end="" : 줄바꿈없음
    # flush=True : 버퍼는 비움
    print(s.content, end="", flush=True)

# %% [markdown]
# ### invoke : 호출

# %%
chain.invoke({"topic": "python miniagent"})

# %%
chain.batch([{"topic": "python mini-agent"},{"topic": "python miniagent"}])

# %% [markdown]
# ### async stream : 비동기 스트림

# %%
async for s in chain.astream({"topic": "YouTube"}):
    print(s.content, end="", flush=True)

# %% [markdown]
# ### async invoke : 비동기 호출

# %%
await chain.ainvoke({"topic": "Stable diffusion"})

# %% [markdown]
# ### async batch : 비동기 배치

# %%
await chain.abatch([{"topic": "NBA"},{"topic": "NFL"}])

# %% [markdown]
# ### async stream 디버깅

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter

# Load the document, split it into chunks, embed each chunk and load it into the vector store.
raw_documents = TextLoader('./choi.txt', encoding='UTF8').load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 4654, which is longer than the specified 1000
# Created a chunk of size 1615, which is longer than the specified 1000
# Created a chunk of size 1867, which is longer than the specified 1000
# Created a chunk of size 1348, which is longer than the specified 1000
# Created a chunk of size 2300, which is longer than the specified 1000
# Created a chunk of size 1447, which is longer than the specified 1000

# %%
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
vectorstore = FAISS.from_documents(documents, embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever()

retriever_chain = (
    {
        "context": retriever.with_config(run_name="Docs"),
        "question": RunnablePassthrough(),
    }
    | prompt
    | model
    | StrOutputParser()
)

async for chunk in retriever_chain.astream_log(
    "최진실은 얼마나 인기가 있었나?", include_names=["Docs"]
):
    print("-" * 40)
    print(chunk)
# Out:
# ----------------------------------------
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '20a69a48-a254-4983-8c79-1193fa9cd7e7',
#             'logs': {},
#             'name': 'RunnableSequence',
#             'streamed_output': [],
#             'type': 'chain'}})
# ----------------------------------------
# RunLogPatch({'op': 'add',
#   'path': '/logs/Docs',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '48fc6890-7aa8-41a8-a7a9-96990ca13890',
#             'metadata': {},
#             'name': 'Docs',
#             'start_time': '2024-06-17T06:07:58.820+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#             'type': 'retriever'}})
# ----------------------------------------
# RunLogPatch({'op': 'add',
#   'path': '/logs/Docs/final_output',
#   'value': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                           Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                           Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                           Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]}},
#  {'op': 'add',
#   'path': '/logs/Docs/end_time',
#   'value': '2024-06-17T06:07:59.168+00:00'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''},
#  {'op': 'replace', 'path': '/final_output', 'value': ''})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '최'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '진'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '실'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '은'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' '},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 '})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '20'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '년'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 동'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '안'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 범'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '국'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범국'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '민'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범국민'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '적'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범국민적'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '으로'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범국민적으로'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 인'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범국민적으로 인'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '기'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범국민적으로 인기'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '를'},
#  {'op': 'replace', 'path': '/final_output', 'value': '최진실은 20년 동안 범국민적으로 인기를'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 끌'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '었'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '으'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '며'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 전'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 연'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '령'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '층'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '을'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 폭'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '넓'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '게'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 아'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '우'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '르'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '는'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 인'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '지'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '도'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '와'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 인'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '기'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '를'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 보'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '여'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '주'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '었습니다'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다.'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 특'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '히'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' '},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '199'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '199'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '0'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '년'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '대'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '에'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '는'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 그'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '녀'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '의'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 위'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '상'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '이'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 매'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '우'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 높'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '아'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '서'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 그'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '와'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 비'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '교'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '되'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '는'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 인'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '물'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '을'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 찾'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '기'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 힘'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기 힘'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '들'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기 힘들'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' 정'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기 힘들 정'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '도'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기 힘들 정도'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '였'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기 힘들 정도였'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '습니다'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기 힘들 정도였습니다'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': '최진실은 20년 동안 범국민적으로 인기를 끌었으며 전 연령층을 폭넓게 아우르는 인지도와 인기를 보여주었습니다. 특히 '
#            '1990년대에는 그녀의 위상이 매우 높아서 그와 비교되는 인물을 찾기 힘들 정도였습니다.'})
# ----------------------------------------
# RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''})

# %% [markdown]
# ### 증분 RunState Streaming

# %%
# diff=False 하면 RunState의 증분 값을 얻음
async for chunk in retriever_chain.astream_log(
    "최진실은 얼마나 인기가 있었나?", include_names=["Docs"], diff=False
):
    print("-" * 40)
    print(chunk)
# Out:
# ----------------------------------------
# RunLog({'final_output': None,
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {},
#  'name': 'RunnableSequence',
#  'streamed_output': [],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': None,
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': None,
#                    'final_output': None,
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': [],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': None,
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': [],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': [''],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['', '최'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['', '최', '진'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['', '최', '진', '실'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실은',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['', '최', '진', '실', '은'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실은 ',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['', '최', '진', '실', '은', ' '],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실은 20',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['', '최', '진', '실', '은', ' ', '20'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실은 20년',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['', '최', '진', '실', '은', ' ', '20', '년'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실은 20년 동',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
# ...
#                      '히',
#                      ' ',
#                      '199',
#                      '0',
#                      '년',
#                      '대',
#                      '에',
#                      '는',
#                      ' 그',
#                      '녀',
#                      '의',
#                      ' 인',
#                      '기',
#                      '가',
#                      ' 현',
#                      '대',
#                      '에',
#                      '도',
#                      ' 비',
#                      '교',
#                      '되',
#                      '는',
#                      ' 인',
#                      '물',
#                      '을',
#                      ' 찾',
#                      '기',
#                      ' 힘',
#                      '들',
#                      ' 정',
#                      '도',
#                      '로',
#                      ' 높',
#                      '았',
#                      '습니다'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실은 20년 동안 범국민적인 인기를 누린 스타였으며, 전 연령층을 폭넓게 아우르는 인지도와 인기를 '
#                  '가졌습니다. 특히 1990년대에는 그녀의 인기가 현대에도 비교되는 인물을 찾기 힘들 정도로 높았습니다.',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['',
#                      '최',
#                      '진',
#                      '실',
#                      '은',
#                      ' ',
#                      '20',
#                      '년',
#                      ' 동',
#                      '안',
#                      ' 범',
#                      '국',
#                      '민',
#                      '적',
#                      '인',
#                      ' 인',
#                      '기',
#                      '를',
#                      ' 누',
#                      '린',
#                      ' 스타',
#                      '였',
#                      '으',
#                      '며',
#                      ',',
#                      ' 전',
#                      ' 연',
#                      '령',
#                      '층',
#                      '을',
#                      ' 폭',
#                      '넓',
#                      '게',
#                      ' 아',
#                      '우',
#                      '르',
#                      '는',
#                      ' 인',
#                      '지',
#                      '도',
#                      '와',
#                      ' 인',
#                      '기',
#                      '를',
#                      ' 가',
#                      '졌',
#                      '습니다',
#                      '.',
#                      ' 특',
#                      '히',
#                      ' ',
#                      '199',
#                      '0',
#                      '년',
#                      '대',
#                      '에',
#                      '는',
#                      ' 그',
#                      '녀',
#                      '의',
#                      ' 인',
#                      '기',
#                      '가',
#                      ' 현',
#                      '대',
#                      '에',
#                      '도',
#                      ' 비',
#                      '교',
#                      '되',
#                      '는',
#                      ' 인',
#                      '물',
#                      '을',
#                      ' 찾',
#                      '기',
#                      ' 힘',
#                      '들',
#                      ' 정',
#                      '도',
#                      '로',
#                      ' 높',
#                      '았',
#                      '습니다',
#                      '.'],
#  'type': 'chain'})
# ----------------------------------------
# RunLog({'final_output': '최진실은 20년 동안 범국민적인 인기를 누린 스타였으며, 전 연령층을 폭넓게 아우르는 인지도와 인기를 '
#                  '가졌습니다. 특히 1990년대에는 그녀의 인기가 현대에도 비교되는 인물을 찾기 힘들 정도로 높았습니다.',
#  'id': '63c5371f-d145-4809-90e0-55049f3b8bb5',
#  'logs': {'Docs': {'end_time': '2024-06-17T06:22:11.711+00:00',
#                    'final_output': {'documents': [Document(page_content='제목 : 최진실에 대한 이야기\n\n1. 개요[편집]\n대한민국의 前 배우.\n\n1988년 광고 모델로 연예계에 데뷔해, 20년 동안 국민적인 인기를 누렸던 인물이다.#\n2. 생애[편집]\n상세 내용 아이콘  자세한 내용은 최진실/생애 문서를 참고하십시오.\n3. 위상, 그리고 인기[편집]\n신인 때부터 사망할 때까지 20년동안 범국민적인 인기를 누렸던 스타였다. 드라마, 영화, 광고, 예능 등을 넘나들며 활발한 활동을 펼쳤고 귀여운 외모와 친근한 성격, 성실함과 겸손함이 갖춰진 이미지로 국민 배우라는 호칭으로 불렸다. 전 연령층을 폭넓게 아우르는 인지도와 인기가 굉장했으며 특히 그녀의 전성기였던 1990년대 당시의 위상은 현재까지도 그와 비견되는 인물을 찾기 힘들 정도로 높았다.[12][13]\n“제가 역사적으로 남을 사람이 되고 싶습니다. 저를 꼭 기억해주세요. 감사합니다.”\n- 1994년 11월 29일 서울 1000년 타임캡슐에 담긴 영상 인터뷰 내용\n\n특히 TV 쪽 배우로는 김희애, 채시라와 함께 한국 TV 드라마의 상징적인 배우 중 1명. <질투>, <별은 내 가슴에>, <그대 그리고 나>, <장밋빛 인생>, <내 생애 마지막 스캔들> 등 거의 모든 드라마가 높은 시청률을 기록했으며 최진실의 커리어 중 드라마 쪽 작품은 시청률에서 실패한 사례가 거의 없을 정도로 인기가 좋았다.[14] 영화 쪽에서도 <남부군>, <나의 사랑 나의 신부>, <마누라 죽이기>, <편지> 등 여러 작품을 히트시키며 티켓파워에 강점을 보이는 충무로의 스타로 거듭났다. 강수연, 심혜진 등과 더불어 한국 영화사에서 가장 높은 티켓파워와 인기를 자랑했던 여배우로 평가받기도 한다. 2000년대 이후로는 드라마 쪽에서만 활동해서 젊은 세대에게는 영화 커리어가 묻히는 경우도 있는데, 드라마 못지않게 영화판에서 최진실이 가졌던 파워도 대단했다.', metadata={'source': './choi.txt'}),
#                                                   Document(page_content='생전 수백여편의 광고에 출연하며 한 때 광고모델 중 역대 최고 개런티를 받었을만큼 광고업계에서 사랑받는 인물이었다. 높은 스타성 때문에 매년 섭외 1순위를 기록했고 장기적으로 모델을 맡는 경우도 많았다. 특히 KT(한국통신)의 경우 1990년대부터 2002년까지 모델로 활동하여 현재도 최진실의 얼굴이 들어간 포스터나 공중전화카드를 종종 찾을 수 있다.\n\n예능에 엄청 자주 출연하는 편은 아니었으나 유머감각이 매우 좋아서 출연하면 나름의 활약을 해주던 인물이었다. 2007년 방송된 무릎팍도사를 보면 알겠지만, 컨셉상 거칠게 진행하는 강호동과 유세윤이 최진실 앞에서 거의 맥을 못 쓸 정도로 프로그램의 분위기를 휘어잡는 모습을 보여주었다.[15] 말년이었던 2008년에는 김구라와 함께 OBS에서 <진실과 구라> 의 메인 MC를 맡기도 했다.\n\n이처럼 최진실은 1990년대부터 길게는 2002년까지 한국에서 최정상급 여배우로 엄청난 인기를 누린 인물이었다. 그러나 2003년부터 조성민과 이혼 다툼을 시작하면서 슬럼프가 찾아왔고, 이미지가 많이 하락하면서 잠시 슬럼프를 가지기도 했다.[16]', metadata={'source': './choi.txt'}),
#                                                   Document(page_content="최진실은 연예계 마당발로 위에 언급한 인물들 외에 탈렌트, 영화 배우, 개그맨, 개그우먼, 가수 모든 분야에서 친분이 많았다.\n8. Right of Publicity[편집]\n최진실은 계약 기간보다 5년을 더 자신의 초상을 사용한 제약업체를 대상으로 5억 원의 손해배상청구 소송을 낸다. 사법부는 2000년 이 제약업체에 4,000만 원을 배상하라고 판결한다. 최진실은 이 재판을 통해 연예인 퍼블리시티권의 초석을 다진다.\n8.1. 공익 활동 1[편집]\n1991년 5월에 소년소녀가장 돕기 자선 공연 열어 공연 수익금 3천만 원을 소년소녀 가장들을 돕는 데 사용한다.\n2002년 6월 7일 재정이 어려운 대학교들에 컴퓨터 등 IT 학습기자재를 지원한다. 김대중 정부의 '사이버 코리아 21' 정책과도 통하는 행보라 거버넌스의 좋은 사례에 해당된다. 통신사 KT와 연대한 활동이라 시너지 효과가 있었다. 최진실에게는 자신을 변함없이 최고 대우로 광고 모델로 기용해 준 KT와의 우정을 표시하는 일이라 의미가 있었다. KT는 2002 부산 아시안 게임 공식 파트너이기도 했다. 관련영상\n2002년 6월 12일 한동대학교에 5천만 원을 기부하고 한동대학교에는 '최진실 장학금'이 생긴다.\n2004년 12월에 밀양 여중생 집단 성폭행 사건 피해자들에게 후원금을 지급한다.\n8.2. 공익 활동 2[편집]\n1993년 금융실명제 광고에 무료로 출연한다.\n1997년 외환 위기 시기에 도산 위기에 처한 기아자동차 광고에 무료로 출연한다.\n2000년 6월에 대중예술인으로서 공공외교관을 자임한다. 1990년대 전반기에 이미 사이판, 스웨덴, 괌 등 외국여행을 많이 한다.\n2004년 10월에 갈 곳 없는 노숙인들과 보육원의 원생들을 돌봐 주었다.\n2004년 12월에 자신의 범죄 피해 경험을 사회적으로 의미를 가질 수 있도록 하면서 자신의 사회적 영향력을 공익에 부합되게 사용하였는데, 범죄 현장을 언론에 공개했다는 이유로 피해자인 광고 모델에게 손해배상금을 청구하는 광고주의 행동에서 사회적 모순을 목격하게 되고 사회가 가정폭력을 인권의 측면에서 바라볼 수 있도록 하기 위해 변호사 강지원 등 여성운동계와 연대한다.\n2005년 12월에 백혈병 환자들과 히말라야를 등반한다.\n2006년 4월에 굿네이버스 친선대사가 된다.\n2007년 7월에 저소득층 아동들을 돌본다.\n2008년 3월에 <최진실의 진실과 구라>에서 동성애를 다루고 싶다고 한다. #\n2008년 4월에 남자 MC 일색 예능계에 일침을 가한다. #\n2008년 3월에 최진영에게 베트남 봉사활동을 권하고 최진실은 드라마 촬영 중이라 2009년에 갈 계획을 세운다. 최진영은 최진실 사망으로 경황이 없는 와중에도 2008년 11월에 베트남 봉사활동을 다녀온다.\n2008년 5월 29일 미국산 소고기 수입과 관련하여 2008년 촛불집회와 뜻을 함께 한다. #\n2008년 7월 13일 연예계 내의 승자독식구조에 대해 성찰한다. #\n2008년 7월 14일 일본의 독도 영유권 주장이나 일본군 위안부 발뺌에 대해 질타한다. #\n2008년 10월 1일 북측 아동들을 위한 자선사업, 봉사활동을 하고 싶다고 한다. # 1989년 영화 '남부군'(1990년)을 찍으면서 남측 반공교육의 문제점을 인식한다. 같은 날, 아프리카에서 봉사활동을 하고 싶다고 한다.", metadata={'source': './choi.txt'}),
#                                                   Document(page_content='최진실은 이전에 이미 자신의 생명을 걸고 불의와 싸울 결심을 하고 있었으며 평소에 주변인들에게 자신의 \'부재\'에 대해 자주 언급해 두었다. # 2004년 드라마 \'장미의 전쟁\'에 출연하기 전에 다음과 같은 기록을 남겼다.\n"저에게는 두 아이가 있고 제 이름과도 같은 \'진실\'이 있습니다. 지금 당장은 아니더라도 그 진실은 제가 죽어서라도 세상 모든 사람들이 알아줄 것이라고 믿고, 이제는 당당히 세상과 맞서 열심히 살 것입니다."\n\n최진실은 자신의 삶을 드라마틱하게 완성시키고 싶어했다.\n"언젠가 저도 죽겠죠. 그 때 저를 위해 뜨거운 눈물 한 방울 흘려줄 사람들이 있으면 돼요. 그럼 비교적 잘 산 거예요. 돈 많고 힘 있을 때 꽃등심 먹은 사람보다 어려울 때 같이 라면 먹어준 사람이 오래가는 법이거든요. 사람 때문에 늘 상처투성이가 되지만 새 살이 돋게 해주는 존재도 역시 사람인 것 같아요. 인생? 그거 우리가 생각하는 것만큼 길지 않아요. 살면서 실패도 하고 좌절도 할 수 있는 거죠. 전 죽는 날까지 드라마틱하게 살고 싶은 사람이에요."\n3.4. 건설사 <신한>에 대한 분노[편집]\n2004년 8월 1일 최진실은 자택에서 조성민에게 폭행을 당했다. # 당연히 최진실은 얼굴을 다쳤고 집안 내부도 어질러졌다. 직접 보지 않아도 폭행 사건이 발생했다고 하면 누구나 추측할 수 있는 상황이며 피해자는 필요하면 그 모습을 공개할 수도 있다. 실제로 최진실은 그렇게 했는데 이유는 조성민이 당시 폭행 사실을 아예 부인하면서 언론에 뿌렸기 때문이다. 여기에서 이후 소송의 주된 쟁점이 등장하는데 단순히 법정에 피해사실을 주장한 것이 아니라 언론과의 인터뷰를 통해 폭행당한 자신의 사진을 공개하였던 것이다. 이는 훗날 소송에서 최진실 측이 패소하는 결정적인 이유가 되었다. 폭행 장면을 언론에 뿌려서 채무불이행책임이 인정된 것이다.', metadata={'source': './choi.txt'})]},
#                    'id': 'de363fe7-7e22-4448-bbdf-b44c7933e3f0',
#                    'metadata': {},
#                    'name': 'Docs',
#                    'start_time': '2024-06-17T06:22:11.391+00:00',
#                    'streamed_output': [],
#                    'streamed_output_str': [],
#                    'tags': ['map:key:context', 'FAISS', 'OpenAIEmbeddings'],
#                    'type': 'retriever'}},
#  'name': 'RunnableSequence',
#  'streamed_output': ['',
#                      '최',
#                      '진',
#                      '실',
#                      '은',
#                      ' ',
#                      '20',
#                      '년',
#                      ' 동',
#                      '안',
#                      ' 범',
#                      '국',
#                      '민',
#                      '적',
#                      '인',
#                      ' 인',
#                      '기',
#                      '를',
#                      ' 누',
#                      '린',
#                      ' 스타',
#                      '였',
#                      '으',
#                      '며',
#                      ',',
#                      ' 전',
#                      ' 연',
#                      '령',
#                      '층',
#                      '을',
#                      ' 폭',
#                      '넓',
#                      '게',
#                      ' 아',
#                      '우',
#                      '르',
#                      '는',
#                      ' 인',
#                      '지',
#                      '도',
#                      '와',
#                      ' 인',
#                      '기',
#                      '를',
#                      ' 가',
#                      '졌',
#                      '습니다',
#                      '.',
#                      ' 특',
#                      '히',
#                      ' ',
#                      '199',
#                      '0',
#                      '년',
#                      '대',
#                      '에',
#                      '는',
#                      ' 그',
#                      '녀',
#                      '의',
#                      ' 인',
#                      '기',
#                      '가',
#                      ' 현',
#                      '대',
#                      '에',
#                      '도',
#                      ' 비',
#                      '교',
#                      '되',
#                      '는',
#                      ' 인',
#                      '물',
#                      '을',
#                      ' 찾',
#                      '기',
#                      ' 힘',
#                      '들',
#                      ' 정',
#                      '도',
#                      '로',
#                      ' 높',
#                      '았',
#                      '습니다',
#                      '.',
#                      ''],
#  'type': 'chain'})

# %% [markdown]
# ### Parallel : 병렬성

# %%
from langchain_core.runnables import RunnableParallel

chain1 = ChatPromptTemplate.from_template("{country} 의 수도는 어디야?") | model
chain2 = ChatPromptTemplate.from_template("{country} 의 면적은 얼마야?") | model

combinded = RunnableParallel(capital=chain1, area=chain2)

# %%
combinded.invoke({"country":"한국"})
# Out:
# {'capital': AIMessage(content='한국의 수도는 서울입니다.', response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 20, 'total_tokens': 32}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-cb796d97-f4fd-46fc-8c0d-259f9064aefe-0', usage_metadata={'input_tokens': 20, 'output_tokens': 12, 'total_tokens': 32}),
#  'area': AIMessage(content='한국의 면적은 약 100,363 제곱 킬로미터입니다.', response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 22, 'total_tokens': 46}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-0cfa0036-22a5-4bd3-a4fc-12a792cc635f-0', usage_metadata={'input_tokens': 22, 'output_tokens': 24, 'total_tokens': 46})}

# %%
combinded.batch([{"country":"한국"},{"country":"미국"}])
